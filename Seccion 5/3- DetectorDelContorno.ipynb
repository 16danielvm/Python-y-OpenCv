# %%
#Deteccion del contorno

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
cd "D:/Universidad/Cursos/Python y OpenCv"
# Out:
# D:\Universidad\Cursos\Python y OpenCv

# %%
imagen = cv2.imread('cara_perro.jpg')#Lee la imagen
plt.imshow(imagen)

# %%
contorno = cv2.Canny(image=imagen,threshold1 = 100,threshold2=100)#Selecciona el contorno
plt.imshow(contorno)

# %%
imagen = cv2.blur(imagen, ksize=(5,5)) #Suaviza la imagen

# %%
contorno = cv2.Canny(image=imagen,threshold1 = 100,threshold2=100) #Selecciona el contorno
plt.imshow(contorno)
