# %%
# Mostrar una imagen en diferentes tamaños

# %%
import matplotlib.pyplot as plt
import cv2

# %%
pwd
# Out:
# 'C:\\Users\\tuto\\AppData\\Local\\Programs\\Microsoft VS Code'

# %%
cd "D:/Universidad/Cursos/Python y OpenCv"
# Out:
# D:\Universidad\Cursos\Python y OpenCv

# %%
imagen = cv2.imread('perro.jpg')
imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
plt.imshow(imagen)

# %%
imagen.shape
# Out:
# (1280, 1920, 3)

# %%
figura = plt.figure(figsize=(20,20)) #Determina el tamañao que ocupa en la pantalla (20x20 pixeles)
lienzo = figura.add_subplot(111)
lienzo.imshow(imagen)

# %%
imagen.shape
# Out:
# (1280, 1920, 3)
