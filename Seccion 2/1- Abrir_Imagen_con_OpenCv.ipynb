# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
cd D:/Universidad/Cursos/Python y OpenCv
# Out:
# D:\Universidad\Cursos\Python y OpenCv

# %%
imagen = cv2.imread('perro.jpg') #Leer imagen y convertirla en array

# %%
type(imagen)
# Out:
# numpy.ndarray

# %%
imagen.shape #Para ver el tamaño de la imagen
# Out:
# (1280, 1920, 3)

# %%
plt.imshow(imagen) #Los colores no son iguales por que entre opencv y matplotlib

# %%
#OpenCV -> BGR(blue green red)
#Matplotlib -> RGB (red green blue)

# %%
imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB) #Modifique el color de BGR a RGB

# %%
plt.imshow(imagen) #Imagen con el orden correcto

# %%
#Imagen en BLANCO Y NEGRO
imagen_blanco_negro = cv2.imread('perro.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imagen_blanco_negro, cmap='gray')
