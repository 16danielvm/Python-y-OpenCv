# %%
#Deteccion (o emparejamiento de imagenes) por caracteristica

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
cd "D:/Universidad/Cursos/Python y OpenCv"
# Out:
# D:\Universidad\Cursos\Python y OpenCv

# %%
cereal = cv2.imread('cereal.png')
cereales = cv2.imread('cereales.png')

# %%
cereal = cv2.cvtColor(cereal, cv2.COLOR_BGR2RGB)
cereales = cv2.cvtColor(cereales,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(cereal)

# %%
plt.imshow(cereales)

# %%
sift = cv2.xfeatures2d.SIFT_create #No FUNCIONA!

# %%
kp1, des1 = sift.detectAndCompute(cereal,None) #NO FUNCIONA!
kp2, des2 = sift.detectAndCompute(cereales,None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-789c24e041a7> in <module>
# ----> 1 kp1, des1 = sift.detectAndCompute(cereal,None) #Claves y Caracteristicas
#       2 kp2, des2 = sift.detectAndCompute(cereales,None)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'detectAndCompute'

# %%
indice = dict(algorithm=0, trees=5)

# %%
busqueda = dict(checks=50)

# %%
Flan = cv2.FlannBasedMatcher(indice,busqueda) #Se usa para encontrar las caracteristicas

# %%
emparejamientos = Flan.knnMatch(des1,des2,k=2) #No funciona
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-73ee34f93dfe> in <module>
# ----> 1 emparejamientos = Flan.knnMatch(des1,des2,k=2)
#
# NameError: name 'des1' is not defined

# %%
mejores = [] #No funciona
for e1, e2 in emparejamientos:
    if e1.distance < 0.7*e2.distance:
        mejores.append([e1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b97977ac653e> in <module>
#       1 mejores = []
# ----> 2 for e1, e2 in emparejamientos:
#       3     if e1.distance < 0.7*e2.distance:
#       4         mejores.append([e1])
#
# NameError: name 'emparejamientos' is not defined

# %%
imagen_emparejamientos = cv2.drawMatchesKnn(cereal,kp1,cereales,kp2,mejores[0:30],None,flags=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-4a38b309c53c> in <module>
# ----> 1 imagen_emparejamientos = cv2.drawMatchesKnn(cereal,kp1,cereales,kp2,mejores[0:30],None,flags=0)
#
# NameError: name 'kp1' is not defined

# %%
imagen_emparejamientos = cv2.cvtColor(imagen_emparejamientos,cv2.COLOR_BGR2RGB)
plt.imshow(imagen_emparejamientos)
