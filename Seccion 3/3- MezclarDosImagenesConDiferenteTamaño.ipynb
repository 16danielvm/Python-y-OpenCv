# %%
#Mezclar imagenes con diferentes tamaños

# %%
import matplotlib.pyplot as plt
import cv2

# %%
pwd
# Out:
# 'C:\\Users\\tuto\\AppData\\Local\\Programs\\Microsoft VS Code'

# %%
cd "D:/Universidad/Cursos/Python y OpenCv"
# Out:
# D:\Universidad\Cursos\Python y OpenCv

# %%
imagen_1 = cv2.imread('perro.jpg')
imagen_1 = cv2.cvtColor(imagen_1,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen_1)

# %%
imagen_2 = cv2.imread('logo-redaitcursos.jpg')

# %%
imagen_2 = cv2.cvtColor(imagen_2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen_2)

# %%
imagen_1.shape
# Out:
# (1280, 1920, 3)

# %%
imagen_2.shape
# Out:
# (99, 318, 3)

# %%
imagen_2 = cv2.resize(imagen_2,(1920,300))

# %%
plt.imshow(imagen_2)

# %%
parte_imagen_1 = imagen_1[: 300]
plt.imshow(parte_imagen_1)

# %%
parte_imagen_mezcla = cv2.addWeighted(src1=parte_imagen_1,alpha=0.5,src2=imagen_2,beta=0.5,gamma=0)

# %%
plt.imshow(parte_imagen_mezcla)

# %%
imagen_1[: 300] = parte_imagen_mezcla #Sustitye la imagen

# %%
plt.imshow(imagen_1)
